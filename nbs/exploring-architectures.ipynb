# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
from fastai.vision import *
from torchsummary import summary
from CinemaNet.custom_head import *
from CinemaNet.train_utils import *
import timm

size=(3,224,224)

# %%
data = get_data('/home/rahul/github_projects/CinemaNet/', to_film_ar(224), 32)
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (5505 items)
# x: ImageList
# Image (3, 224, 398),Image (3, 224, 398),Image (3, 224, 398),Image (3, 224, 398),Image (3, 224, 398)
# y: CategoryList
# Medium,Medium,Medium,Medium,Medium
# Path: /home/rahul/github_projects/CinemaNet;
#
# Valid: LabelList (600 items)
# x: ImageList
# Image (3, 224, 398),Image (3, 224, 398),Image (3, 224, 398),Image (3, 224, 398),Image (3, 224, 398)
# y: CategoryList
# Medium,Medium,Medium,Medium,Medium
# Path: /home/rahul/github_projects/CinemaNet;
#
# Test: None

# %%
torch.hub.list('rwightman/gen-efficientnet-pytorch')
# Out:
# Using cache found in /home/rahul/.cache/torch/hub/rwightman_gen-efficientnet-pytorch_master
# ['efficientnet_b0',
#  'efficientnet_b1',
#  'efficientnet_b2',
#  'fbnetc_100',
#  'mixnet_l',
#  'mixnet_m',
#  'mixnet_s',
#  'mixnet_xl',
#  'mnasnet_a1',
#  'mnasnet_b1',
#  'mobilenetv3_rw',
#  'spnasnet_100',
#  'tf_efficientnet_b0',
#  'tf_efficientnet_b0_ap',
#  'tf_efficientnet_b1',
#  'tf_efficientnet_b1_ap',
#  'tf_efficientnet_b2',
#  'tf_efficientnet_b2_ap',
#  'tf_efficientnet_b3',
#  'tf_efficientnet_b3_ap',
#  'tf_efficientnet_b4',
#  'tf_efficientnet_b4_ap',
#  'tf_efficientnet_b5',
#  'tf_efficientnet_b5_ap',
#  'tf_efficientnet_b6',
#  'tf_efficientnet_b6_ap',
#  'tf_efficientnet_b7',
#  'tf_efficientnet_b7_ap',
#  'tf_efficientnet_b8_ap',
#  'tf_efficientnet_cc_b0_4e',
#  'tf_efficientnet_cc_b0_8e',
#  'tf_efficientnet_cc_b1_8e',
#  'tf_efficientnet_el',
#  'tf_efficientnet_em',
#  'tf_efficientnet_es',
#  'tf_mixnet_l',
#  'tf_mixnet_m',
#  'tf_mixnet_s',
# ...

# %% [markdown]
# ## MobileNets
#
# * MobileNetV3 - Large_100
# * MobileNetV3 - Large_075
# * MobileNetV3 - Large_Minimal_100
# * MobileNetV2
# * MobileNetV3 - Small_100
# * MobileNetV3 - Small_075
# * MobileNetV3 - Small_Minimal_100

# %%
from geffnet.mobilenetv3 import mobilenetv3_large_075, mobilenetv3_large_100, mobilenetv3_large_minimal_100

# %% [markdown]
# ### MobileNetV3 - LARGE_100

# %%
summary(mobilenetv3_large_100().cuda(), size)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 16, 112, 112]             432
#        BatchNorm2d-2         [-1, 16, 112, 112]              32
#          HardSwish-3         [-1, 16, 112, 112]               0
#             Conv2d-4         [-1, 16, 112, 112]             144
#        BatchNorm2d-5         [-1, 16, 112, 112]              32
#               ReLU-6         [-1, 16, 112, 112]               0
#           Identity-7         [-1, 16, 112, 112]               0
#             Conv2d-8         [-1, 16, 112, 112]             256
#        BatchNorm2d-9         [-1, 16, 112, 112]              32
#          Identity-10         [-1, 16, 112, 112]               0
# DepthwiseSeparableConv-11         [-1, 16, 112, 112]               0
#            Conv2d-12         [-1, 64, 112, 112]           1,024
#       BatchNorm2d-13         [-1, 64, 112, 112]             128
# ...

# %% [markdown]
# ### MobileNetV3 - LARGE_075

# %%
summary(mobilenetv3_large_075().cuda(), size)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 16, 112, 112]             432
#        BatchNorm2d-2         [-1, 16, 112, 112]              32
#          HardSwish-3         [-1, 16, 112, 112]               0
#             Conv2d-4         [-1, 16, 112, 112]             144
#        BatchNorm2d-5         [-1, 16, 112, 112]              32
#               ReLU-6         [-1, 16, 112, 112]               0
#           Identity-7         [-1, 16, 112, 112]               0
#             Conv2d-8         [-1, 16, 112, 112]             256
#        BatchNorm2d-9         [-1, 16, 112, 112]              32
#          Identity-10         [-1, 16, 112, 112]               0
# DepthwiseSeparableConv-11         [-1, 16, 112, 112]               0
#            Conv2d-12         [-1, 64, 112, 112]           1,024
#       BatchNorm2d-13         [-1, 64, 112, 112]             128
# ...

# %% [markdown]
# ### MobileNetV3 - LARGE_MINIMAL_100

# %%
summary(mobilenetv3_large_minimal_100().cuda(), size)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 16, 112, 112]             432
#        BatchNorm2d-2         [-1, 16, 112, 112]              32
#               ReLU-3         [-1, 16, 112, 112]               0
#             Conv2d-4         [-1, 16, 112, 112]             144
#        BatchNorm2d-5         [-1, 16, 112, 112]              32
#               ReLU-6         [-1, 16, 112, 112]               0
#           Identity-7         [-1, 16, 112, 112]               0
#             Conv2d-8         [-1, 16, 112, 112]             256
#        BatchNorm2d-9         [-1, 16, 112, 112]              32
#          Identity-10         [-1, 16, 112, 112]               0
# DepthwiseSeparableConv-11         [-1, 16, 112, 112]               0
#            Conv2d-12         [-1, 64, 112, 112]           1,024
#       BatchNorm2d-13         [-1, 64, 112, 112]             128
# ...

# %% [markdown]
# ### MobileNetV2

# %%
summary(models.mobilenet_v2().cuda(), size)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 32, 112, 112]             864
#        BatchNorm2d-2         [-1, 32, 112, 112]              64
#              ReLU6-3         [-1, 32, 112, 112]               0
#             Conv2d-4         [-1, 32, 112, 112]             288
#        BatchNorm2d-5         [-1, 32, 112, 112]              64
#              ReLU6-6         [-1, 32, 112, 112]               0
#             Conv2d-7         [-1, 16, 112, 112]             512
#        BatchNorm2d-8         [-1, 16, 112, 112]              32
#   InvertedResidual-9         [-1, 16, 112, 112]               0
#            Conv2d-10         [-1, 96, 112, 112]           1,536
#       BatchNorm2d-11         [-1, 96, 112, 112]             192
#             ReLU6-12         [-1, 96, 112, 112]               0
#            Conv2d-13           [-1, 96, 56, 56]             864
# ...

# %% [markdown]
# ### MobileNetV3_RW (?)

# %%
from geffnet.mobilenetv3 import mobilenetv3_rw

# %%
summary(mobilenetv3_rw().cuda(), size)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 16, 112, 112]             432
#        BatchNorm2d-2         [-1, 16, 112, 112]              32
#          HardSwish-3         [-1, 16, 112, 112]               0
#             Conv2d-4         [-1, 16, 112, 112]             144
#        BatchNorm2d-5         [-1, 16, 112, 112]              32
#               ReLU-6         [-1, 16, 112, 112]               0
#           Identity-7         [-1, 16, 112, 112]               0
#             Conv2d-8         [-1, 16, 112, 112]             256
#        BatchNorm2d-9         [-1, 16, 112, 112]              32
#          Identity-10         [-1, 16, 112, 112]               0
# DepthwiseSeparableConv-11         [-1, 16, 112, 112]               0
#            Conv2d-12         [-1, 64, 112, 112]           1,024
#       BatchNorm2d-13         [-1, 64, 112, 112]             128
# ...

# %%
from geffnet.mobilenetv3 import mobilenetv3_small_075, mobilenetv3_small_100, mobilenetv3_small_minimal_100

# %% [markdown]
# ### MobileNetV3 - SMALL_075

# %%
summary(mobilenetv3_small_075().cuda(), size)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 16, 112, 112]             432
#        BatchNorm2d-2         [-1, 16, 112, 112]              32
#          HardSwish-3         [-1, 16, 112, 112]               0
#             Conv2d-4           [-1, 16, 56, 56]             144
#        BatchNorm2d-5           [-1, 16, 56, 56]              32
#               ReLU-6           [-1, 16, 56, 56]               0
#  AdaptiveAvgPool2d-7             [-1, 16, 1, 1]               0
#             Conv2d-8              [-1, 8, 1, 1]             136
#               ReLU-9              [-1, 8, 1, 1]               0
#            Conv2d-10             [-1, 16, 1, 1]             144
#     SqueezeExcite-11           [-1, 16, 56, 56]               0
#            Conv2d-12           [-1, 16, 56, 56]             256
#       BatchNorm2d-13           [-1, 16, 56, 56]              32
# ...

# %% [markdown]
# ### MobileNetV3 - SMALL_100

# %%
summary(mobilenetv3_small_100().cuda(), size)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 16, 112, 112]             432
#        BatchNorm2d-2         [-1, 16, 112, 112]              32
#          HardSwish-3         [-1, 16, 112, 112]               0
#             Conv2d-4           [-1, 16, 56, 56]             144
#        BatchNorm2d-5           [-1, 16, 56, 56]              32
#               ReLU-6           [-1, 16, 56, 56]               0
#  AdaptiveAvgPool2d-7             [-1, 16, 1, 1]               0
#             Conv2d-8              [-1, 8, 1, 1]             136
#               ReLU-9              [-1, 8, 1, 1]               0
#            Conv2d-10             [-1, 16, 1, 1]             144
#     SqueezeExcite-11           [-1, 16, 56, 56]               0
#            Conv2d-12           [-1, 16, 56, 56]             256
#       BatchNorm2d-13           [-1, 16, 56, 56]              32
# ...

# %% [markdown]
# ### MobileNetV3 - SMALL_MINIMAL_100

# %%
summary(mobilenetv3_small_minimal_100().cuda(), size)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 16, 112, 112]             432
#        BatchNorm2d-2         [-1, 16, 112, 112]              32
#               ReLU-3         [-1, 16, 112, 112]               0
#             Conv2d-4           [-1, 16, 56, 56]             144
#        BatchNorm2d-5           [-1, 16, 56, 56]              32
#               ReLU-6           [-1, 16, 56, 56]               0
#           Identity-7           [-1, 16, 56, 56]               0
#             Conv2d-8           [-1, 16, 56, 56]             256
#        BatchNorm2d-9           [-1, 16, 56, 56]              32
#          Identity-10           [-1, 16, 56, 56]               0
# DepthwiseSeparableConv-11           [-1, 16, 56, 56]               0
#            Conv2d-12           [-1, 72, 56, 56]           1,152
#       BatchNorm2d-13           [-1, 72, 56, 56]             144
# ...

# %%
x = torch.hub.load('rwightman/gen-efficientnet-pytorch', 'mixnet_l')
type(x)
# Out:
# Using cache found in /home/rahul/.cache/torch/hub/rwightman_gen-efficientnet-pytorch_master
# geffnet.gen_efficientnet.GenEfficientNet

# %%
torch.hub.list('rwightman/gen-efficientnet-pytorch')
# Out:
# Using cache found in /home/rahul/.cache/torch/hub/rwightman_gen-efficientnet-pytorch_master
# ['efficientnet_b0',
#  'efficientnet_b1',
#  'efficientnet_b2',
#  'fbnetc_100',
#  'mixnet_l',
#  'mixnet_m',
#  'mixnet_s',
#  'mixnet_xl',
#  'mnasnet_a1',
#  'mnasnet_b1',
#  'mobilenetv3_rw',
#  'spnasnet_100',
#  'tf_efficientnet_b0',
#  'tf_efficientnet_b0_ap',
#  'tf_efficientnet_b1',
#  'tf_efficientnet_b1_ap',
#  'tf_efficientnet_b2',
#  'tf_efficientnet_b2_ap',
#  'tf_efficientnet_b3',
#  'tf_efficientnet_b3_ap',
#  'tf_efficientnet_b4',
#  'tf_efficientnet_b4_ap',
#  'tf_efficientnet_b5',
#  'tf_efficientnet_b5_ap',
#  'tf_efficientnet_b6',
#  'tf_efficientnet_b6_ap',
#  'tf_efficientnet_b7',
#  'tf_efficientnet_b7_ap',
#  'tf_efficientnet_b8_ap',
#  'tf_efficientnet_cc_b0_4e',
#  'tf_efficientnet_cc_b0_8e',
#  'tf_efficientnet_cc_b1_8e',
#  'tf_efficientnet_el',
#  'tf_efficientnet_em',
#  'tf_efficientnet_es',
#  'tf_mixnet_l',
#  'tf_mixnet_m',
#  'tf_mixnet_s',
# ...

# %% [markdown]
# ## MixNets
#
# * MixNet - Large
# * MixNet - Medium
# * MixNet - Small

# %%
from geffnet.gen_efficientnet import mixnet_l, mixnet_m, mixnet_s

# %% [markdown]
# ### MixNet - LARGE

# %%
summary(mixnet_l().cuda(), size)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 32, 112, 112]             864
#        BatchNorm2d-2         [-1, 32, 112, 112]              64
#               ReLU-3         [-1, 32, 112, 112]               0
#             Conv2d-4         [-1, 32, 112, 112]             288
#        BatchNorm2d-5         [-1, 32, 112, 112]              64
#               ReLU-6         [-1, 32, 112, 112]               0
#           Identity-7         [-1, 32, 112, 112]               0
#             Conv2d-8         [-1, 32, 112, 112]           1,024
#        BatchNorm2d-9         [-1, 32, 112, 112]              64
#          Identity-10         [-1, 32, 112, 112]               0
# DepthwiseSeparableConv-11         [-1, 32, 112, 112]               0
#            Conv2d-12         [-1, 96, 112, 112]           1,536
#            Conv2d-13         [-1, 96, 112, 112]           1,536
# ...

# %% [markdown]
# ### MixNet - MEDIUM

# %%
summary(mixnet_m().cuda(), size)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 24, 112, 112]             648
#        BatchNorm2d-2         [-1, 24, 112, 112]              48
#               ReLU-3         [-1, 24, 112, 112]               0
#             Conv2d-4         [-1, 24, 112, 112]             216
#        BatchNorm2d-5         [-1, 24, 112, 112]              48
#               ReLU-6         [-1, 24, 112, 112]               0
#           Identity-7         [-1, 24, 112, 112]               0
#             Conv2d-8         [-1, 24, 112, 112]             576
#        BatchNorm2d-9         [-1, 24, 112, 112]              48
#          Identity-10         [-1, 24, 112, 112]               0
# DepthwiseSeparableConv-11         [-1, 24, 112, 112]               0
#            Conv2d-12         [-1, 72, 112, 112]             864
#            Conv2d-13         [-1, 72, 112, 112]             864
# ...

# %% [markdown]
# ### MixNet - SMALL

# %%
summary(mixnet_s().cuda(), size)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 16, 112, 112]             432
#        BatchNorm2d-2         [-1, 16, 112, 112]              32
#               ReLU-3         [-1, 16, 112, 112]               0
#             Conv2d-4         [-1, 16, 112, 112]             144
#        BatchNorm2d-5         [-1, 16, 112, 112]              32
#               ReLU-6         [-1, 16, 112, 112]               0
#           Identity-7         [-1, 16, 112, 112]               0
#             Conv2d-8         [-1, 16, 112, 112]             256
#        BatchNorm2d-9         [-1, 16, 112, 112]              32
#          Identity-10         [-1, 16, 112, 112]               0
# DepthwiseSeparableConv-11         [-1, 16, 112, 112]               0
#            Conv2d-12         [-1, 48, 112, 112]             384
#            Conv2d-13         [-1, 48, 112, 112]             384
# ...

# %%
from geffnet.gen_efficientnet import fbnetc_100

# %% [markdown]
# ## FBNet-C_100

# %%
summary(fbnetc_100().cuda(), size)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 16, 112, 112]             432
#        BatchNorm2d-2         [-1, 16, 112, 112]              32
#               ReLU-3         [-1, 16, 112, 112]               0
#             Conv2d-4         [-1, 16, 112, 112]             256
#        BatchNorm2d-5         [-1, 16, 112, 112]              32
#               ReLU-6         [-1, 16, 112, 112]               0
#             Conv2d-7         [-1, 16, 112, 112]             144
#        BatchNorm2d-8         [-1, 16, 112, 112]              32
#               ReLU-9         [-1, 16, 112, 112]               0
#          Identity-10         [-1, 16, 112, 112]               0
#            Conv2d-11         [-1, 16, 112, 112]             256
#       BatchNorm2d-12         [-1, 16, 112, 112]              32
#  InvertedResidual-13         [-1, 16, 112, 112]               0
# ...

# %% [markdown]
# ## Layer Groups

# %%
mobilenet_split = lambda m: (m[0][3][3][2], m[1])
learn = cnn_learner(data, mobilenetv3_large_100, cut=None, split_on=mobilenet_split)

[len(grp) for grp in learn.layer_groups]
# Out:
# [82, 81, 10]
